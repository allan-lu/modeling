# %% [markdown]
# # US Elections

# %% [markdown]
# ### Data Sources
#
# - MIT Elections lab
# - US Census CPS Tool Creator
# - US States polygons

# %% [markdown]
# ## Getting Started

# %% [markdown]
# Import all libraries needed for the project.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import json
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## 1. Reading data and setting up initial dataframes

# %% [markdown]
# Import states shapefile as a dataframe.
#
# Set the state `FID` to the index.

# %%
states_geo_df = gpd.read_file("./data/states.shp")
states_geo_df = states_geo_df.set_index("FID")
states_geo_df.head()
# Out:
#                                               geometry
# FID
# 05   POLYGON ((558.824 -323.366, 559.353 -323.342, ...
# 06   MULTIPOLYGON (((38.962 -255.141, 38.572 -253.1...
# 17   POLYGON ((625.736 -191.428, 627.145 -193.035, ...
# 20   POLYGON ((501.558 -245.737, 502.088 -245.737, ...
# 28   MULTIPOLYGON (((633.352 -373.244, 633.332 -373...

# %% [markdown]
# Import elections data.
#
# Delete all rows with write in votes.
#
# Create an `FID` column from `state_fips`.

# %%
p_elec_data = pd.read_csv("./data/1976-2016-president.csv")
p_elec_data = p_elec_data[p_elec_data.writein == False]
p_elec_data["FID"] = p_elec_data["state_fips"].astype(int).astype(str)
p_elec_data["FID"] = p_elec_data["FID"].apply(lambda x: '{0:0>2}'.format(x))
p_elec_data.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# 1             Ford, Gerald                  republican    False
# 2           Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin ""Ben""                 prohibition    False
# 4                Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes FID
# 0          659170     1182850  20171015    NaN  01
# 1          504070     1182850  20171015    NaN  01
# 2            9198     1182850  20171015    NaN  01
# 3            6669     1182850  20171015    NaN  01
# 4            1954     1182850  20171015    NaN  01

# %% [markdown]
# For Minnesota and North Dakota, change their democratic parties to `democrat` in column `party`.

# %%
p_elec_data[(p_elec_data.state_po == 'MN') & (p_elec_data.year == 2000)]
# Out:
#       year      state state_po  state_fips  state_cen  state_ic        office  \
# 2210  2000  Minnesota       MN          27         41        33  US President
# 2211  2000  Minnesota       MN          27         41        33  US President
# 2212  2000  Minnesota       MN          27         41        33  US President
# 2213  2000  Minnesota       MN          27         41        33  US President
# 2214  2000  Minnesota       MN          27         41        33  US President
# 2215  2000  Minnesota       MN          27         41        33  US President
# 2216  2000  Minnesota       MN          27         41        33  US President
# 2217  2000  Minnesota       MN          27         41        33  US President
#
#                       candidate                    party  writein  \
# 2210                   Gore, Al  democratic-farmer-labor    False
# 2211            Bush, George W.               republican    False
# 2212               Nader, Ralph                    green    False
# 2213  Buchanan, Patrick ""Pat""   reform party minnesota    False
# 2214              Browne, Harry              libertarian    False
# 2215           Phillips, Howard       constitution party    False
# 2216  Buchanan, Patrick ""Pat""             reform party    False
# 2217              Harris, James        socialist workers    False
#
#       candidatevotes  totalvotes   version  notes FID
# 2210         1168266     2438685  20171015    NaN  27
# 2211         1109659     2438685  20171015    NaN  27
# 2212          126696     2438685  20171015    NaN  27
# 2213           22166     2438685  20171015    NaN  27
# 2214            5282     2438685  20171015    NaN  27
# 2215            3272     2438685  20171015    NaN  27
# 2216            2294     2438685  20171015    NaN  27
# 2217            1022     2438685  20171015    NaN  27

# %%
p_elec_data["party"] = np.where((p_elec_data.party == 'democratic-farmer-labor'), 
                                'democrat', p_elec_data.party)
p_elec_data.loc[(p_elec_data.party == 'democratic-farmer-labor') 
                | (p_elec_data.party == 'democratic-nonpartisan league') 
                | (p_elec_data.party == 'democratic-npl'),
                "party"] = 'democrat'
p_elec_data[(p_elec_data.state_po == 'MN') & (p_elec_data.year == 2000)]
# Out:
#       year      state state_po  state_fips  state_cen  state_ic        office  \
# 2210  2000  Minnesota       MN          27         41        33  US President
# 2211  2000  Minnesota       MN          27         41        33  US President
# 2212  2000  Minnesota       MN          27         41        33  US President
# 2213  2000  Minnesota       MN          27         41        33  US President
# 2214  2000  Minnesota       MN          27         41        33  US President
# 2215  2000  Minnesota       MN          27         41        33  US President
# 2216  2000  Minnesota       MN          27         41        33  US President
# 2217  2000  Minnesota       MN          27         41        33  US President
#
#                       candidate                   party  writein  \
# 2210                   Gore, Al                democrat    False
# 2211            Bush, George W.              republican    False
# 2212               Nader, Ralph                   green    False
# 2213  Buchanan, Patrick ""Pat""  reform party minnesota    False
# 2214              Browne, Harry             libertarian    False
# 2215           Phillips, Howard      constitution party    False
# 2216  Buchanan, Patrick ""Pat""            reform party    False
# 2217              Harris, James       socialist workers    False
#
#       candidatevotes  totalvotes   version  notes FID
# 2210         1168266     2438685  20171015    NaN  27
# 2211         1109659     2438685  20171015    NaN  27
# 2212          126696     2438685  20171015    NaN  27
# 2213           22166     2438685  20171015    NaN  27
# 2214            5282     2438685  20171015    NaN  27
# 2215            3272     2438685  20171015    NaN  27
# 2216            2294     2438685  20171015    NaN  27
# 2217            1022     2438685  20171015    NaN  27

# %% [markdown]
# ## 2. Manipulating data

# %% [markdown]
# Create a dictionary where the keys are every 4 years from `2004` to `2016`.
#
# The year's corresponding dataframe is the value.
#
# Create and calculate the `party ratio` column.

# %%
gby_year = p_elec_data.groupby("year")

elections_dict = {}
for year in gby_year.groups.keys():
    if year >= 2004:
        p_elections_df = pd.DataFrame()
        group = gby_year.get_group(year)
        df = group[["FID", "state", "state_po"]].groupby('FID').first()
        
        # pivot the party column to create two columns democrat and republican votes
        # calculate the party ratio from the pivoted column
        pivot_df = pd.pivot_table(group[(group.party == 'democrat') | (group.party == 'republican')], index='FID', columns='party', values='candidatevotes')
        ratio = pd.Series(pivot_df.democrat / (pivot_df.democrat + pivot_df.republican) * 1000, name='party_ratio')
        group = df.join(ratio)
        elections_dict[year] = group
elections_dict[2004].head()
# Out:
#           state state_po  party_ratio
# FID
# 01      Alabama       AL   371.022286
# 02       Alaska       AK   367.737170
# 04      Arizona       AZ   447.249950
# 05     Arkansas       AR   450.642517
# 06   California       CA   550.413205

# %% [markdown]
# Read in demographic data.
#
# Create a `demo_dict` dictionary with a dataframe for each corresponding year.

# %%
demo_dict = {}
for year in gby_year.groups.keys():
    if year >= 2004:
        demo_dict[year] = pd.read_csv("./data/states-demo-{}.csv".format(year))
        demo_dict[year] = demo_dict[year].set_index("state")
demo_dict[2016].head()
# Out:
#        total_pop  age_under_18  age_18_24  age_25_44  age_45_64  age_65_plus  \
# state
# AL          4820          1090        440       1212       1365          713
# AK           703           187         65        200        172           80
# AZ          6728          1607        611       1778       1697         1035
# AR          2951           722        238        757        778          456
# CA         39081          9126       3953      10800      10126         5076
#
#        race_white  race_black  race_native  race_asian  ...  \
# state                                                   ...
# AL           3286        1310           24          96  ...
# AK            442          25          116          53  ...
# AZ           5735         315          249         221  ...
# AR           2353         458           14          55  ...
# CA          28306        2484          758        6046  ...
#
#        edu_child_under_15  edu_no_hs_diploma  edu_high_school  \
# state
# AL                    896                760             1247
# AK                    153                 69              164
# AZ                   1321               1047             1307
# AR                    583                450              777
# CA                   7559               5964             7168
#
#        edu_some_college  edu_college_degree_plus  irp_below_50  irp_50_100  \
# state
# AL                 1073                      845           311         473
# AK                  162                      156            33          31
# AZ                 1672                     1380           519         638
# AR                  635                      506           222         253
# CA                 8939                     9451          2500        2941
#
#        irp_100_300  irp_300_500  irp_500_plus
# state
# AL            1814         1133          1089
# AK             197          187           254
# AZ            2579         1430          1563
# AR            1212          621           643
# CA           13371         8482         11788
#
# [5 rows x 22 columns]

# %% [markdown]
# Create another `demo_perc_dict` with the demographic percentages instead of numbers of people.

# %%
demo_perc_dict = {}
for key in demo_dict.keys():
    demo_perc_dict[key] = demo_dict[key].divide(demo_dict[key].total_pop, axis=0) * 100
    demo_perc_dict[key].total_pop = demo_dict[key].total_pop
demo_perc_dict[2016].head()
# Out:
#        total_pop  age_under_18  age_18_24  age_25_44  age_45_64  age_65_plus  \
# state
# AL          4820     22.614108   9.128631  25.145228  28.319502    14.792531
# AK           703     26.600284   9.246088  28.449502  24.466572    11.379801
# AZ          6728     23.885256   9.081451  26.426873  25.222949    15.383472
# AR          2951     24.466283   8.065063  25.652321  26.363944    15.452389
# CA         39081     23.351501  10.114890  27.634912  25.910289    12.988409
#
#        race_white  race_black  race_native  race_asian  ...  \
# state                                                   ...
# AL      68.174274   27.178423     0.497925    1.991701  ...
# AK      62.873400    3.556188    16.500711    7.539118  ...
# AZ      85.240785    4.681926     3.700951    3.284780  ...
# AR      79.735683   15.520163     0.474415    1.863775  ...
# CA      72.429058    6.356030     1.939561   15.470433  ...
#
#        edu_child_under_15  edu_no_hs_diploma  edu_high_school  \
# state
# AL              18.589212          15.767635        25.871369
# AK              21.763869           9.815078        23.328592
# AZ              19.634364          15.561831        19.426278
# AR              19.756015          15.249068        26.330058
# CA              19.341880          15.260613        18.341394
#
#        edu_some_college  edu_college_degree_plus  irp_below_50  irp_50_100  \
# state
# AL            22.261411                17.531120      6.452282    9.813278
# AK            23.044097                22.190612      4.694168    4.409673
# AZ            24.851367                20.511296      7.714031    9.482759
# AR            21.518129                17.146730      7.522874    8.573365
# CA            22.873007                24.183107      6.396970    7.525396
#
#        irp_100_300  irp_300_500  irp_500_plus
# state
# AL       37.634855    23.506224     22.593361
# AK       28.022760    26.600284     36.130868
# AZ       38.332342    21.254459     23.231272
# AR       41.070823    21.043714     21.789224
# CA       34.213556    21.703641     30.162995
#
# [5 rows x 22 columns]

# %% [markdown]
# Join all the dataframes in the dictionaries: `elections_dict` and `demo_perc_dict` into a new dataframe called `states_dict`.

# %%
states_dict = {}
for key, df in elections_dict.items():
    df = df.reset_index().merge(demo_perc_dict[key], how='left', left_on='state_po', right_on='state').set_index("FID")
    states_dict[key] = states_geo_df.join(df)
states_dict[2016].head()
# Out:
#                                               geometry        state state_po  \
# FID
# 05   POLYGON ((558.824 -323.366, 559.353 -323.342, ...     Arkansas       AR
# 06   MULTIPOLYGON (((38.962 -255.141, 38.572 -253.1...   California       CA
# 17   POLYGON ((625.736 -191.428, 627.145 -193.035, ...     Illinois       IL
# 20   POLYGON ((501.558 -245.737, 502.088 -245.737, ...       Kansas       KS
# 28   MULTIPOLYGON (((633.352 -373.244, 633.332 -373...  Mississippi       MS
#
#      party_ratio  total_pop  age_under_18  age_18_24  age_25_44  age_45_64  \
# FID
# 05    357.148623       2951     24.466283   8.065063  25.652321  26.363944
# 06    661.282205      39081     23.351501  10.114890  27.634912  25.910289
# 17    590.200514      12683     23.164866   8.578412  27.438303  25.979658
# 20    388.885297       2849     26.360126   8.213408  25.517726  25.974026
# 28    409.101527       2947     24.872752   9.026128  25.619274  26.060400
#
#      age_65_plus  ...  edu_child_under_15  edu_no_hs_diploma  edu_high_school  \
# FID               ...
# 05     15.452389  ...           19.756015          15.249068        26.330058
# 06     12.988409  ...           19.341880          15.260613        18.341394
# 17     14.838761  ...           19.143736          11.416857        20.823149
# 20     13.934714  ...           20.849421          12.565813        19.620920
# 28     14.421446  ...           20.122158          16.728877        24.126230
#
#      edu_some_college  edu_college_degree_plus  irp_below_50  irp_50_100  \
# FID
# 05          21.518129                17.146730      7.522874    8.573365
# 06          22.873007                24.183107      6.396970    7.525396
# 17          21.635260                26.988883      5.085548    5.803043
# 20          23.552124                23.446823      4.878905    9.301509
# 28          24.465558                14.557177      8.313539   10.756702
#
#      irp_100_300  irp_300_500  irp_500_plus
# FID
# 05     41.070823    21.043714     21.789224
# 06     34.213556    21.703641     30.162995
# 17     31.325396    25.214855     32.579043
# 20     33.871534    24.464724     27.448227
# 28     44.451985    19.239905     17.237869
#
# [5 rows x 26 columns]

# %% [markdown]
# Save the dataframes as shapefiles

# %%
for key, df in states_dict.items():
    df.to_file("./data/state_elections_{}".format(key))

# %% [markdown]
# ## 3. Exploring the data

# %% [markdown]
# Visualize the dataframes in the `states_dict` dictionary by year.

# %%
for key, df in states_dict.items():
    plt.rcParams['figure.figsize'] = [20, 10]
    df.plot(column='irp_below_50', cmap='RdYlGn_r', edgecolor='grey')
    plt.title(key, size='16')
    plt.xticks(())
    plt.yticks(())

plt.show()

# %% [markdown]
# Join all the separate dataframes into one and tidy it.

# %%
tidy_states_df = pd.DataFrame()
for key, df in states_dict.items():
    df = pd.DataFrame.copy(df)
    df.insert(1, "year", key)
    tidy_states_df = pd.concat([df, tidy_states_df])
tidy_states_df.head()
# Out:
#                                               geometry  year        state  \
# FID
# 05   POLYGON ((558.824 -323.366, 559.353 -323.342, ...  2016     Arkansas
# 06   MULTIPOLYGON (((38.962 -255.141, 38.572 -253.1...  2016   California
# 17   POLYGON ((625.736 -191.428, 627.145 -193.035, ...  2016     Illinois
# 20   POLYGON ((501.558 -245.737, 502.088 -245.737, ...  2016       Kansas
# 28   MULTIPOLYGON (((633.352 -373.244, 633.332 -373...  2016  Mississippi
#
#     state_po  party_ratio  total_pop  age_under_18  age_18_24  age_25_44  \
# FID
# 05        AR   357.148623       2951     24.466283   8.065063  25.652321
# 06        CA   661.282205      39081     23.351501  10.114890  27.634912
# 17        IL   590.200514      12683     23.164866   8.578412  27.438303
# 20        KS   388.885297       2849     26.360126   8.213408  25.517726
# 28        MS   409.101527       2947     24.872752   9.026128  25.619274
#
#      age_45_64  ...  edu_child_under_15  edu_no_hs_diploma  edu_high_school  \
# FID             ...
# 05   26.363944  ...           19.756015          15.249068        26.330058
# 06   25.910289  ...           19.341880          15.260613        18.341394
# 17   25.979658  ...           19.143736          11.416857        20.823149
# 20   25.974026  ...           20.849421          12.565813        19.620920
# 28   26.060400  ...           20.122158          16.728877        24.126230
#
#      edu_some_college  edu_college_degree_plus  irp_below_50  irp_50_100  \
# FID
# 05          21.518129                17.146730      7.522874    8.573365
# 06          22.873007                24.183107      6.396970    7.525396
# 17          21.635260                26.988883      5.085548    5.803043
# 20          23.552124                23.446823      4.878905    9.301509
# 28          24.465558                14.557177      8.313539   10.756702
#
#      irp_100_300  irp_300_500  irp_500_plus
# FID
# 05     41.070823    21.043714     21.789224
# 06     34.213556    21.703641     30.162995
# 17     31.325396    25.214855     32.579043
# 20     33.871534    24.464724     27.448227
# 28     44.451985    19.239905     17.237869
#
# [5 rows x 27 columns]

# %% [markdown]
# Create a scatterplot matrix to visualize the relationship of the variables

# %%
col = ["age_45_64", "race_white", "edu_college_degree_plus", "irp_100_300"]
col = ["party_ratio"] + col
par_df = tidy_states_df[col][(tidy_states_df.index != '11') & (tidy_states_df.index != '15')]
par_df.head()

plt.rcParams['figure.figsize'] = [20, 20]
scatter_matrix(par_df, marker='x')

plt.show()

# %% [markdown]
# ## 4. Machine Learning

# %% [markdown]
# Create the independent `X` and dependent `y` variables as dataframes.
#
# Split the test data into train and test data.
#
# Fit the train data and create a regression model.

# %%
X = tidy_states_df[["age_45_64", "race_white", "edu_college_degree_plus"]]
y = tidy_states_df[["party_ratio"]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=51, random_state=101)

lm = LinearRegression()
regr = lm.fit(X_train, y_train)
regr
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Run the model on the test data.
#
# Compare the predicted `y` with the expected `y`.

# %%
test = regr.predict(X_test)
plt.figure(figsize=(7, 7))
plt.scatter(y_test, test)
plt.show()

# %% [markdown]
# Acquire the r-squared value for the regression model.

# %%
regr.score(X_test, y_test)
# Out:
# 0.6811194737033199

# %% [markdown]
# Read 2018 data into a new dataset.
#
# Join the geometry column to the dataset.

# %%
demo_df = pd.read_csv("./data/states-demo-2018.csv")
demo_df = demo_df.set_index("state")
demo_p_df = demo_df.divide(demo_df.total_pop, axis=0) * 100
demo_p_df.total_pop = demo_df.total_pop

fid_s = states_dict[next(iter(states_dict))]["state_po"]
fid_s = pd.Series(fid_s.index.values, index = fid_s)

demo_p_df["FID"] = fid_s
demo_p_df = demo_p_df.set_index("FID")
demo_p_df = states_geo_df.join(demo_p_df)
demo_p_df.head()
# Out:
#                                               geometry  total_pop  \
# FID
# 05   POLYGON ((558.824 -323.366, 559.353 -323.342, ...       2924
# 06   MULTIPOLYGON (((38.962 -255.141, 38.572 -253.1...      39237
# 17   POLYGON ((625.736 -191.428, 627.145 -193.035, ...      12604
# 20   POLYGON ((501.558 -245.737, 502.088 -245.737, ...       2870
# 28   MULTIPOLYGON (((633.352 -373.244, 633.332 -373...       2947
#
#      age_under_18  age_18_24  age_25_44  age_45_64  age_65_plus  race_white  \
# FID
# 05      24.384405   9.678523  24.555404  25.034200    16.381669   78.864569
# 06      22.970665   8.996610  29.199480  24.568647    14.264597   72.617682
# 17      22.960965   9.441447  26.102825  26.309108    15.185655   76.864487
# 20      24.459930   9.268293  26.132404  22.787456    17.386760   86.062718
# 28      24.024432   8.890397  25.687139  25.721072    15.676960   58.839498
#
#      race_black  race_native  ...  edu_child_under_15  edu_no_hs_diploma  \
# FID                           ...
# 05    15.424077     0.786594  ...           19.357045          15.663475
# 06     6.356245     1.396641  ...           18.900528          14.654535
# 17    14.281181     0.864805  ...           18.232307          11.464614
# 20     5.749129     1.045296  ...           20.836237          11.463415
# 28    37.699355     0.644723  ...           19.714964          15.507296
#
#      edu_high_school  edu_some_college  edu_college_degree_plus  irp_below_50  \
# FID
# 05         25.000000         21.819425                18.194254      6.497948
# 06         18.107908         22.476234                25.860795      5.698703
# 17         21.342431         21.635989                27.316725      4.974611
# 20         20.940767         22.055749                24.703833      6.515679
# 28         23.820835         24.194096                16.762810      8.279606
#
#      irp_50_100  irp_100_300  irp_300_500  irp_500_plus
# FID
# 05     8.276334    41.244870    21.614227     22.400821
# 06     6.718149    33.659556    21.461885     32.464256
# 17     5.966360    29.641384    25.817201     33.600444
# 20     8.188153    30.278746    25.017422     30.000000
# 28     9.976247    40.210383    23.617238     17.916525
#
# [5 rows x 23 columns]

# %% [markdown]
# Map the predicted results for 2018.

# %%
X_pred = demo_p_df[["age_45_64", "race_white", "edu_college_degree_plus"]]
y_pred = lm.predict(X_pred)

pred_df = pd.DataFrame.copy(demo_p_df)
pred_df.insert(1, "pred_ratio", lm.predict(X_pred))

base = pred_df[pred_df.pred_ratio > 500].plot(color='blue', edgecolor='white')
pred_df[pred_df.pred_ratio < 500].plot(ax=base, color='red', edgecolor='black')

plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# A different coloring option.

# %%
pred_df.plot(column='pred_ratio', cmap='bwr_r', scheme='quantiles', edgecolor='black')

plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# View statistical analysis of the regression model.

# %%
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
print('R-squared: %.2f' 
      % regr.score(X_test, y_test))
# Out:
# Coefficients:
#  [[ 8.0653535  -2.252289   14.00516443]]
# Mean squared error: 31256.24
# Coefficient of determination: -0.53
# R-squared: 0.68
